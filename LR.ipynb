# %% [markdown]
# <a href="https://colab.research.google.com/github/gulshan0201/Machine-Learning-Practical-/blob/main/LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model

# %%
from google.colab import drive
drive.mount('/content/drive')  # Authorize once
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Choose a folder in Drive to store artifacts. It will be created if missing.

# %%
import os

BASE_DIR = '/content/drive/MyDrive/LR'  # change if you like
os.makedirs(BASE_DIR, exist_ok=True)

ARTIFACT_PATH = os.path.join(BASE_DIR, 'dbscan_artifacts.joblib')
print('Artifacts will be saved to:', ARTIFACT_PATH)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
pip install pandas openpyxl

# %%
excel_file_path = '/content/drive/MyDrive/LR/house_price.xlsx'
df = pd.read_excel(excel_file_path)
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color='red', marker="+")
plt.plot(df.area, reg.predict(df[['area']]), color='blue')

# %%
reg = linear_model.LinearRegression()  # creating an object of Linear regression
reg.fit(df[['area']], df.price)  # reg.fit is mainly training the linear regression model
# Out:
# LinearRegression()

# %% [markdown]
# After training the model let us predict some prices of house based on there sqr feet

# %%
# import numpy as np # import numpy for reshaping

reg.predict(np.array(4300).reshape(-1, 1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([764503.42465753])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %% [markdown]
# # Traditional formula based y = mx+c

# %%
135.78767123*4300+180616.43835616432
# Out:
# 764503.4246451643

# %%
df = pd.read_excel('/content/drive/MyDrive/LR/areas.xlsx')
df.head()
# Out:
#    areas
# 0   1200
# 1   2220
# 2   4400
# 3   1500
# 4   1900

# %%
predicted_prices = reg.predict(np.array(df))
print(predicted_prices)
# Out:
# [ 343561.64383562  482065.06849315  778082.19178082  384297.94520548
#   438613.01369863  913869.8630137  1063236.30136986 1199023.97260274
#   357140.4109589 ]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Adding a new coloumn named prices in the dataframe

# %%
df['price'] = predicted_prices
df.head()
# Out:
#    areas          price
# 0   1200  343561.643836
# 1   2220  482065.068493
# 2   4400  778082.191781
# 3   1500  384297.945205
# 4   1900  438613.013699

# %%
df.to_excel("areas.xlsx", index=False)
